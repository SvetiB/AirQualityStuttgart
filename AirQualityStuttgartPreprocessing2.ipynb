# %% [markdown]
# # Libraries and Global Settings

# %%
import pandas as pd  # work with Pandas dataframes
import numpy as np  # work with numpy arrays
from datetime import datetime # work with datetimes

import pandas_profiling # for EDA

import seaborn as sns # Visualizations 
#from sklearn import datasets
from yellowbrick.target import FeatureCorrelation # Visualization for Features Selection
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy import stats

from sklearn import preprocessing
from sklearn.impute import KNNImputer

import warnings # Funktionalität zur Unterdrückung von Warnungen
warnings.filterwarnings('ignore')
# Out:
# C:\Users\elvir\AppData\Local\Continuum\anaconda3\envs\condatascience\lib\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.metrics.classification module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
# %%html
# <style>
# table {float:left}
# </style>
# Out:
# <style>
# table {float:left}
# </style>

# %% [markdown]
# # Business Understanding

# %% [markdown]
# ## Business Case Definition and Understanding

# %% [markdown]
# This project is part of the module "Machine Learning" (ML) at the Hochschule der Medien Stuttgart in the summer semster 2020.
# In this case we have to realize a project in the context of ML.
# The topic of this project comprises the analysis of the air quality in the center of Stuttgart, especially at the measuring point Stuttgart-Neckartor.

# %% [markdown]
# ## Goal Definition

# %% [markdown]
# The goal of this project is to analyze the air pollution caused by particulates (Feinstaub) in conjuction with other air specific and traffic based features.
# Furthermore, we would like to detemine if a prediction of the air pollution based on these features is possible.
# The use case of this prediction is to deliver valuable information for the warning system in Stuttgart.

# %% [markdown]
# ## Metrics Specification for Performance Measuring

# %% [markdown]
# The data samples consist of the target values for particulates and the features used as input parameters for the forecasting of our target values.
#
# | Column name | Additional information | Description |  Used As |
# | :------- | :------: | :------- | :-------  |
# | Datum		 |  |  Datum | Feature |
# | Temp. (°C)	| Mittel	| Lufttemperatur|  Feature |
# | Temp. (°C).1	| Max	| Lufttemperatur|  Feature |
# | Temp. (°C).2	| Min	| Lufttemperatur|  Feature |
# | Feuchte (%)	| Mittel	| Relative Luftfeuchte|  Feature |
# | WG (m/s)	| Mittel	| Windgeschwindigkeit|  Feature |
# | WG (m/s).1	| Max	| Windgeschwindigkeit|  Feature |
# | WR (Grad)	| Mittel	| Windrichtung|  Feature |
# | Druck (hPa)	| Mittel	| Absoluter Luftdruck|  Feature |
# | Niederschlag (l/m²)	| Summe	| Niederschlag|  Feature |
# | Globalstr. (W/m²)	| Mittel	| Globalstrahlung|  Feature |
# | Str.-Bilanz (W/m²)	| Mittel	| Strahlungsbilanz|  Feature |
# | UVA-Str. (W/m²)	| Mittel	| UV-A Strahlung|  Feature |
# | UVB-Str. (W/m²)	| Mittel	| UV-B  Strahlung|  Feature |
# | NO (µg/m³)	| Mittel	| Stickstoffmonoxid|  Feature |
# | NO2 (µg/m³)	| Mittel	| Stickstoffdioxid|  Feature |
# | O3 (µg/m³)	| Mittel	| Ozon|  Feature |
# | PM10 (µg/m³)	| Mittel	| Feinstaub (PM10)| Outcome Variable |
# | PM2,5 (µg/m³)	| Mittel	| Feinstaub (PM2.5)| not relevant |
# | Verkehraufkommen	| Summe	| Verkehraufkommen |  Feature |

# %% [markdown]
# # Data Understanding

# %% [markdown]
# data must be gathered, accessed, understood and described. Quantitiy and qualitity of the data must be assessed on a high-level.

# %% [markdown]
# ## Data Gathering

# %% [markdown]
# Air data:

# %%
# https://www.stadtklima-stuttgart.de/index.php?luft_messdaten_download

# %% [markdown]
# Traffic data:

# %%
# https://www.bast.de/BASt_2017/DE/Verkehrstechnik/Fachthemen/v2-verkehrszaehlung/Aktuell/zaehl_aktuell_node.html?nn=1819516&cms_detail=8440&cms_map=0

# %% [markdown]
# ## Data Access

# %%
# define funktion to import each ExcelTab in one pandas dataframe
def excelImport(list_1, path_1, list_2, path_2):
    for i in list_1:
        if i == 2000:
            df = pd.read_excel(path_1, sheet_name=str(i), header=6)
            df = df.dropna(subset=['Datum'])
        else:
            df_temp = pd.read_excel(path_1, sheet_name=str(i), header=6)
            df_temp = df_temp.dropna(subset=['Datum'])
            df = df.append(df_temp, sort=False, ignore_index=True)
        #print(str(i))
    for j in list_2:
        df_temp2 = pd.read_excel(path_2, sheet_name=j, header=6)
        df_temp2 = df_temp2.rename(columns={"PM2,5 (µg/m³)": "PM2.5 (µg/m³)"})
        df_temp2 = df_temp2.dropna(subset=['Datum'])
        df = df.append(df_temp2, sort=False, ignore_index=True)
        #print(j)
    return df

# %%
list_1 = list(range(2000, 2020, 1))
list_2 = ["Jan. 2020", "Feb. 2020", "März 2020", "April 2020", "Mai 2020"]
path_1 = "Data/SZ-Tages-Werte-2000-2019.xlsx"
path_2 = "Data/S-Mitte-SZ-Tages-Werte-2020.xlsx"

df_air = excelImport(list_1, path_1, list_2, path_2)

# %%
df_air.head(5)
# Out:
#        Datum Temp. (°C) Temp. (°C).1 Temp. (°C).2 Feuchte (%) WG (m/s)  \
# 0 2000-01-01      3.718          5.7        2.138       86.83   1.9599
# 1 2000-01-02      3.848        6.706        1.299       90.69  2.17291
# 2 2000-01-03      1.463        2.706       0.4088       88.48  2.29521
# 3 2000-01-04      4.934        7.747       0.8828       77.37  3.57498
# 4 2000-01-05      6.917        10.07        2.034       83.52  2.23721
#
#   WG (m/s).1 WR (Grad) Druck (hPa) Globalstr. (W/m²)  ... UVB-Str. (W/m²)  \
# 0       7.45   234.923       991.8               NaN  ...           0.031
# 1      7.891   222.511       996.9               NaN  ...         0.04113
# 2       6.03   220.181       996.2               NaN  ...         0.02885
# 3      9.703   220.885       989.9               NaN  ...          0.0351
# 4      9.115   220.554       989.7               NaN  ...         0.03395
#
#   NO (µg/m³) NO2 (µg/m³) O3 (µg/m³) SO2 (µg/m³) CO (mg/m³)  \
# 0        NaN         NaN       13.6       10.38     0.9109
# 1        NaN         NaN      16.91       10.74      0.887
# 2        NaN         NaN       15.4       10.29     0.8394
# 3        NaN         NaN      22.43       13.42     0.7822
# 4        NaN         NaN      16.03       14.27      1.189
#
#   Niederschlag (l/m²) Str.-Bilanz (W/m²) PM10 (µg/m³) PM2.5 (µg/m³)
# 0                 NaN                NaN          NaN           NaN
# 1                 NaN                NaN          NaN           NaN
# 2                 NaN                NaN          NaN           NaN
# 3                 NaN                NaN          NaN           NaN
# 4                 NaN                NaN          NaN           NaN
#
# [5 rows x 21 columns]

# %%
df_air['Datum'][0]
# Out:
# Timestamp('2000-01-01 00:00:00')

# %%
df_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7457 entries, 0 to 7456
# Data columns (total 21 columns):
# Datum                  7457 non-null datetime64[ns]
# Temp. (°C)             7331 non-null object
# Temp. (°C).1           7334 non-null object
# Temp. (°C).2           7320 non-null object
# Feuchte (%)            6987 non-null object
# WG (m/s)               7433 non-null object
# WG (m/s).1             7347 non-null object
# WR (Grad)              7433 non-null object
# Druck (hPa)            7299 non-null object
# Globalstr. (W/m²)      7283 non-null object
# UVA-Str. (W/m²)        7254 non-null object
# UVB-Str. (W/m²)        7253 non-null object
# NO (µg/m³)             6755 non-null object
# NO2 (µg/m³)            6742 non-null object
# O3 (µg/m³)             7004 non-null object
# SO2 (µg/m³)            3136 non-null object
# CO (mg/m³)             1277 non-null object
# Niederschlag (l/m²)    6969 non-null object
# Str.-Bilanz (W/m²)     6727 non-null object
# PM10 (µg/m³)           6269 non-null object
# PM2.5 (µg/m³)          1938 non-null object
# dtypes: datetime64[ns](1), object(20)
# memory usage: 1.2+ MB

# %%
df_air['Datum'] = df_air['Datum'].dt.normalize()
#df_air['Datum'] = df_air['Datum'].dt.date

# %%
df_air.head(5)
# Out:
#        Datum Temp. (°C) Temp. (°C).1 Temp. (°C).2 Feuchte (%) WG (m/s)  \
# 0 2000-01-01      3.718          5.7        2.138       86.83   1.9599
# 1 2000-01-02      3.848        6.706        1.299       90.69  2.17291
# 2 2000-01-03      1.463        2.706       0.4088       88.48  2.29521
# 3 2000-01-04      4.934        7.747       0.8828       77.37  3.57498
# 4 2000-01-05      6.917        10.07        2.034       83.52  2.23721
#
#   WG (m/s).1 WR (Grad) Druck (hPa) Globalstr. (W/m²)  ... UVB-Str. (W/m²)  \
# 0       7.45   234.923       991.8               NaN  ...           0.031
# 1      7.891   222.511       996.9               NaN  ...         0.04113
# 2       6.03   220.181       996.2               NaN  ...         0.02885
# 3      9.703   220.885       989.9               NaN  ...          0.0351
# 4      9.115   220.554       989.7               NaN  ...         0.03395
#
#   NO (µg/m³) NO2 (µg/m³) O3 (µg/m³) SO2 (µg/m³) CO (mg/m³)  \
# 0        NaN         NaN       13.6       10.38     0.9109
# 1        NaN         NaN      16.91       10.74      0.887
# 2        NaN         NaN       15.4       10.29     0.8394
# 3        NaN         NaN      22.43       13.42     0.7822
# 4        NaN         NaN      16.03       14.27      1.189
#
#   Niederschlag (l/m²) Str.-Bilanz (W/m²) PM10 (µg/m³) PM2.5 (µg/m³)
# 0                 NaN                NaN          NaN           NaN
# 1                 NaN                NaN          NaN           NaN
# 2                 NaN                NaN          NaN           NaN
# 3                 NaN                NaN          NaN           NaN
# 4                 NaN                NaN          NaN           NaN
#
# [5 rows x 21 columns]

# %%
df_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7457 entries, 0 to 7456
# Data columns (total 21 columns):
# Datum                  7457 non-null datetime64[ns]
# Temp. (°C)             7331 non-null object
# Temp. (°C).1           7334 non-null object
# Temp. (°C).2           7320 non-null object
# Feuchte (%)            6987 non-null object
# WG (m/s)               7433 non-null object
# WG (m/s).1             7347 non-null object
# WR (Grad)              7433 non-null object
# Druck (hPa)            7299 non-null object
# Globalstr. (W/m²)      7283 non-null object
# UVA-Str. (W/m²)        7254 non-null object
# UVB-Str. (W/m²)        7253 non-null object
# NO (µg/m³)             6755 non-null object
# NO2 (µg/m³)            6742 non-null object
# O3 (µg/m³)             7004 non-null object
# SO2 (µg/m³)            3136 non-null object
# CO (mg/m³)             1277 non-null object
# Niederschlag (l/m²)    6969 non-null object
# Str.-Bilanz (W/m²)     6727 non-null object
# PM10 (µg/m³)           6269 non-null object
# PM2.5 (µg/m³)          1938 non-null object
# dtypes: datetime64[ns](1), object(20)
# memory usage: 1.2+ MB

# %%
df_air['Datum'][0]
# Out:
# Timestamp('2000-01-01 00:00:00')

# %% [markdown]
# Import function to import the traffic data

# %%
def trafficImport(path, listYear):
    mydateparser = lambda x: pd.datetime.strptime(x, "%y%m%d")
    
    for i in listYear:
        
        path_full = path + str(i) + ".csv"    
    
        if i == 2003:
            df_traffic = pd.read_csv(path_full,
                         header=0,
                         sep=";",
                         parse_dates=['Datum'],
                         date_parser=mydateparser,
                         index_col=['Datum'])   
        
        else:
            df_traffic_temp = pd.read_csv(path_full,
                         header=0,
                         sep=";",
                         parse_dates=['Datum'],
                         date_parser=mydateparser,
                         index_col=['Datum'])
            df_traffic = df_traffic.append(df_traffic_temp, sort=False)
            
    df_traffic = df_traffic[["KFZ_R1", "KFZ_R2"]]
    df_traffic = df_traffic.resample('d').sum()
    df_traffic.loc[:,'KFZ_ges'] = df_traffic.loc[:,'KFZ_R1'].add(df_traffic.loc[:,'KFZ_R2'])
    df_traffic = df_traffic[["KFZ_ges"]] 
    return df_traffic

# %%
path = "Data/zst8440_"
listYear = list(range(2003, 2019, 1))

df_traffic = trafficImport(path, listYear)

# %%
df_traffic.tail(5)
# Out:
#             KFZ_ges
# Datum
# 2018-12-27    63079
# 2018-12-28    63118
# 2018-12-29    54339
# 2018-12-30    41674
# 2018-12-31    37776

# %% [markdown]
# Merge function to merge the two dataframes to one:

# %%
df_total = pd.merge(df_air, df_traffic, how='outer', on='Datum')

# %%
df_total.head()
# Out:
#        Datum Temp. (°C) Temp. (°C).1 Temp. (°C).2 Feuchte (%) WG (m/s)  \
# 0 2000-01-01      3.718          5.7        2.138       86.83   1.9599
# 1 2000-01-02      3.848        6.706        1.299       90.69  2.17291
# 2 2000-01-03      1.463        2.706       0.4088       88.48  2.29521
# 3 2000-01-04      4.934        7.747       0.8828       77.37  3.57498
# 4 2000-01-05      6.917        10.07        2.034       83.52  2.23721
#
#   WG (m/s).1 WR (Grad) Druck (hPa) Globalstr. (W/m²)  ... NO (µg/m³)  \
# 0       7.45   234.923       991.8               NaN  ...        NaN
# 1      7.891   222.511       996.9               NaN  ...        NaN
# 2       6.03   220.181       996.2               NaN  ...        NaN
# 3      9.703   220.885       989.9               NaN  ...        NaN
# 4      9.115   220.554       989.7               NaN  ...        NaN
#
#   NO2 (µg/m³) O3 (µg/m³) SO2 (µg/m³) CO (mg/m³) Niederschlag (l/m²)  \
# 0         NaN       13.6       10.38     0.9109                 NaN
# 1         NaN      16.91       10.74      0.887                 NaN
# 2         NaN       15.4       10.29     0.8394                 NaN
# 3         NaN      22.43       13.42     0.7822                 NaN
# 4         NaN      16.03       14.27      1.189                 NaN
#
#   Str.-Bilanz (W/m²) PM10 (µg/m³) PM2.5 (µg/m³) KFZ_ges
# 0                NaN          NaN           NaN     NaN
# 1                NaN          NaN           NaN     NaN
# 2                NaN          NaN           NaN     NaN
# 3                NaN          NaN           NaN     NaN
# 4                NaN          NaN           NaN     NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Data Description and Understanding

# %% [markdown]
# ### Data Quantity

# %% [markdown]
# ### Data Quality

# %% [markdown]
# **Removal of dashes and double dashes**

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7458 entries, 0 to 7457
# Data columns (total 22 columns):
# Datum                  7458 non-null datetime64[ns]
# Temp. (°C)             7331 non-null object
# Temp. (°C).1           7334 non-null object
# Temp. (°C).2           7320 non-null object
# Feuchte (%)            6987 non-null object
# WG (m/s)               7433 non-null object
# WG (m/s).1             7347 non-null object
# WR (Grad)              7433 non-null object
# Druck (hPa)            7299 non-null object
# Globalstr. (W/m²)      7283 non-null object
# UVA-Str. (W/m²)        7254 non-null object
# UVB-Str. (W/m²)        7253 non-null object
# NO (µg/m³)             6755 non-null object
# NO2 (µg/m³)            6742 non-null object
# O3 (µg/m³)             7004 non-null object
# SO2 (µg/m³)            3136 non-null object
# CO (mg/m³)             1277 non-null object
# Niederschlag (l/m²)    6969 non-null object
# Str.-Bilanz (W/m²)     6727 non-null object
# PM10 (µg/m³)           6269 non-null object
# PM2.5 (µg/m³)          1938 non-null object
# KFZ_ges                5845 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(20)
# memory usage: 1.3+ MB

# %%
df_total.loc[df_total['PM10 (µg/m³)'] == '--']
# Out:
#           Datum Temp. (°C) Temp. (°C).1 Temp. (°C).2 Feuchte (%) WG (m/s)  \
# 6222 2017-01-13        2.9          4.5         -9.4        57.5      4.9
# 6273 2017-03-05        8.6         12.8          5.7        60.7      2.8
# 6284 2017-03-16       11.2         19.4          4.4        55.5      1.1
# 6285 2017-03-17       13.4         20.6          8.8        52.8      2.3
# 6286 2017-03-18         10         11.6          8.1        72.4        3
# ...         ...        ...          ...          ...         ...      ...
# 7385 2020-03-21        5.4         11.2          3.1        81.9      2.9
# 7386 2020-03-22        4.2          8.4          0.9        54.4      3.7
# 7393 2020-03-29        5.9         12.5          3.1        69.2      2.1
# 7394 2020-03-30        3.7          7.9          0.2        48.7      2.8
# 7395 2020-03-31        3.8          8.8         -0.9        47.2      1.9
#
#      WG (m/s).1 WR (Grad) Druck (hPa) Globalstr. (W/m²)  ... NO (µg/m³)  \
# 6222       13.8     224.4      965.63              27.3  ...        NaN
# 6273        8.4     241.5      971.63             120.2  ...        0.4
# 6284        3.9     223.3      992.21             169.3  ...         42
# 6285        7.7     231.2      983.81               137  ...       18.1
# 6286        7.3     235.6      979.88              35.1  ...        0.9
# ...         ...       ...         ...               ...  ...        ...
# 7385        7.1        61      989.83              14.1  ...        1.7
# 7386        8.8        70      994.91             161.4  ...        0.9
# 7393        5.5        25      988.96              28.6  ...          1
# 7394        8.3       211      993.51             166.2  ...        1.8
# 7395        5.5       209      993.66             153.7  ...        8.4
#
#      NO2 (µg/m³) O3 (µg/m³) SO2 (µg/m³) CO (mg/m³) Niederschlag (l/m²)  \
# 6222         NaN       45.8         NaN        NaN                0.08
# 6273         9.3       54.7         NaN        NaN                 1.3
# 6284        60.3        5.7         NaN        NaN                   0
# 6285        29.6       34.6         NaN        NaN                   0
# 6286        11.2       43.4         NaN        NaN                10.2
# ...          ...        ...         ...        ...                 ...
# 7385        13.4        9.5         NaN        NaN                13.9
# 7386         8.2        9.5         NaN        NaN                 0.1
# 7393        12.3        9.5         NaN        NaN                 3.3
# 7394        15.4        9.5         NaN        NaN                   0
# 7395        22.3        9.4         NaN        NaN                   0
#
#      Str.-Bilanz (W/m²) PM10 (µg/m³) PM2.5 (µg/m³)  KFZ_ges
# 6222              -26.8           --           NaN  86737.0
# 6273               36.7           --            --  57545.0
# 6284               43.4           --            --  92500.0
# 6285               40.1           --            --  91461.0
# 6286                -14           --            --  69042.0
# ...                 ...          ...           ...      ...
# 7385              -23.7           --          21.3      NaN
# 7386               69.8           --          12.1      NaN
# 7393                -21           --            --      NaN
# 7394               93.4           --            --      NaN
# 7395               64.3           --           4.6      NaN
#
# [394 rows x 22 columns]

# %%
df_total.replace("--", np.nan, inplace=True)

# %%
df_total
# Out:
#           Datum  Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)  \
# 0    2000-01-01       3.718         5.700        2.1380        86.83
# 1    2000-01-02       3.848         6.706        1.2990        90.69
# 2    2000-01-03       1.463         2.706        0.4088        88.48
# 3    2000-01-04       4.934         7.747        0.8828        77.37
# 4    2000-01-05       6.917        10.070        2.0340        83.52
# ...         ...         ...           ...           ...          ...
# 7453 2020-05-28      17.300        21.800       12.4000        48.90
# 7454 2020-05-29      16.200        21.200        9.4000        44.80
# 7455 2020-05-30      15.900        20.600        9.3000        47.40
# 7456 2020-05-31      16.700        21.900       10.4000        42.70
# 7457 2016-01-29         NaN           NaN           NaN          NaN
#
#       WG (m/s)  WG (m/s).1   WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  ...  \
# 0     1.959896       7.450  234.922917       991.80                NaN  ...
# 1     2.172913       7.891  222.511250       996.90                NaN  ...
# 2     2.295208       6.030  220.181250       996.20                NaN  ...
# 3     3.574979       9.703  220.885417       989.90                NaN  ...
# 4     2.237208       9.115  220.554167       989.70                NaN  ...
# ...        ...         ...         ...          ...                ...  ...
# 7453  2.400000       6.100   28.000000       996.45              235.7  ...
# 7454  2.200000       5.600  129.000000       993.43              237.9  ...
# 7455  2.400000       7.100   27.000000       989.46              215.4  ...
# 7456  2.000000       5.300   61.000000       988.27              258.8  ...
# 7457       NaN         NaN         NaN          NaN                NaN  ...
#
#       NO (µg/m³)  NO2 (µg/m³)  O3 (µg/m³)  SO2 (µg/m³) CO (mg/m³)  \
# 0            NaN          NaN        13.6        10.38     0.9109
# 1            NaN          NaN       16.91        10.74     0.8870
# 2            NaN          NaN        15.4        10.29     0.8394
# 3            NaN          NaN       22.43        13.42     0.7822
# 4            NaN          NaN       16.03        14.27     1.1890
# ...          ...          ...         ...          ...        ...
# 7453         4.2         23.5         NaN          NaN        NaN
# 7454         2.8         18.7         NaN          NaN        NaN
# 7455         2.4         18.4         NaN          NaN        NaN
# 7456         1.6         13.0         NaN          NaN        NaN
# 7457         NaN          NaN         NaN          NaN        NaN
#
#       Niederschlag (l/m²)  Str.-Bilanz (W/m²)  PM10 (µg/m³)  PM2.5 (µg/m³)  \
# 0                     NaN                 NaN           NaN            NaN
# 1                     NaN                 NaN           NaN            NaN
# 2                     NaN                 NaN           NaN            NaN
# 3                     NaN                 NaN           NaN            NaN
# 4                     NaN                 NaN           NaN            NaN
# ...                   ...                 ...           ...            ...
# 7453                  0.0               136.1           NaN            NaN
# 7454                  0.0               105.5           NaN            NaN
# 7455                  0.0               104.9           NaN            NaN
# 7456                  0.0               131.8           NaN            NaN
# 7457                  NaN                 NaN           NaN            NaN
#
#       KFZ_ges
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 7453      NaN
# 7454      NaN
# 7455      NaN
# 7456      NaN
# 7457  94073.0
#
# [7458 rows x 22 columns]

# %%
df_total.loc[df_total['PM10 (µg/m³)'] == '--']
# Out:
# Empty DataFrame
# Columns: [Datum, Temp. (°C), Temp. (°C).1, Temp. (°C).2, Feuchte (%), WG (m/s), WG (m/s).1, WR (Grad), Druck (hPa), Globalstr. (W/m²), UVA-Str. (W/m²), UVB-Str. (W/m²), NO (µg/m³), NO2 (µg/m³), O3 (µg/m³), SO2 (µg/m³), CO (mg/m³), Niederschlag (l/m²), Str.-Bilanz (W/m²), PM10 (µg/m³), PM2.5 (µg/m³), KFZ_ges]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_total.loc[df_total['PM10 (µg/m³)'] == '-'].head(5)
# Out:
#           Datum  Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)  \
# 6044 2016-07-19        25.1          31.5          17.1         50.5
# 6045 2016-07-20        27.6          34.7          18.8         45.6
# 6361 2017-06-01        22.2          28.4          15.1         50.3
# 6362 2017-06-02        22.9          29.3          19.8         54.4
# 6363 2017-06-03        22.7          29.7          17.6         63.1
#
#       WG (m/s)  WG (m/s).1  WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  ...  \
# 6044       1.6         2.4      217.3       984.12              305.7  ...
# 6045       1.6         2.7      217.6       979.71              300.2  ...
# 6361       1.2         4.2      210.0       988.66              296.6  ...
# 6362       1.3         7.0      231.0       985.61              211.0  ...
# 6363       1.3         6.7      251.6       981.87              219.7  ...
#
#       NO (µg/m³)  NO2 (µg/m³)  O3 (µg/m³)  SO2 (µg/m³) CO (mg/m³)  \
# 6044         7.6         23.8           -          NaN        NaN
# 6045         5.5         21.3           -          NaN        NaN
# 6361         6.9         40.2        28.3          NaN        NaN
# 6362         5.8         42.4        33.9          NaN        NaN
# 6363         2.6         19.1        35.3          NaN        NaN
#
#       Niederschlag (l/m²)  Str.-Bilanz (W/m²)  PM10 (µg/m³)  PM2.5 (µg/m³)  \
# 6044                  0.0               150.3             -              -
# 6045                  0.0               148.4             -              -
# 6361                  0.0               296.6             -              -
# 6362                  0.0               211.0             -              -
# 6363                  0.0               219.7             -              -
#
#       KFZ_ges
# 6044  89889.0
# 6045  88879.0
# 6361  93576.0
# 6362  92571.0
# 6363  67340.0
#
# [5 rows x 22 columns]

# %%
df_total.replace("-", np.nan, inplace=True)

# %%
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7458 entries, 0 to 7457
# Data columns (total 22 columns):
# Datum                  7458 non-null datetime64[ns]
# Temp. (°C)             7331 non-null float64
# Temp. (°C).1           7334 non-null float64
# Temp. (°C).2           7320 non-null float64
# Feuchte (%)            6987 non-null float64
# WG (m/s)               7433 non-null float64
# WG (m/s).1             7347 non-null float64
# WR (Grad)              7433 non-null float64
# Druck (hPa)            7299 non-null float64
# Globalstr. (W/m²)      7283 non-null float64
# UVA-Str. (W/m²)        7254 non-null float64
# UVB-Str. (W/m²)        7253 non-null float64
# NO (µg/m³)             6710 non-null float64
# NO2 (µg/m³)            6697 non-null float64
# O3 (µg/m³)             6960 non-null float64
# SO2 (µg/m³)            3136 non-null float64
# CO (mg/m³)             1277 non-null float64
# Niederschlag (l/m²)    6969 non-null float64
# Str.-Bilanz (W/m²)     6727 non-null float64
# PM10 (µg/m³)           5843 non-null float64
# PM2.5 (µg/m³)          1451 non-null float64
# KFZ_ges                5845 non-null float64
# dtypes: datetime64[ns](1), float64(21)
# memory usage: 1.3 MB

# %%
df_total.describe()
# Out:
#         Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)     WG (m/s)  \
# count  7331.000000   7334.000000   7320.000000  6987.000000  7433.000000
# mean     12.035986     16.741980      7.934110    66.402367     1.981501
# std       7.451711      8.826068      6.605726    12.034543     0.728233
# min     -11.430000     -7.732000    -14.280000     0.051950     0.600000
# 25%       6.200500      9.690500      2.888000    57.455000     1.500000
# 50%      12.210000     16.950000      8.041500    67.270000     1.800000
# 75%      17.800000     23.540000     13.220000    75.600000     2.300000
# max      31.460000     39.540000     24.200000    95.030000     7.155542
#
#         WG (m/s).1    WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  \
# count  7347.000000  7433.000000  7299.000000        7283.000000
# mean      7.621054   194.121793   984.818118         127.758414
# std       3.329142    61.581520     7.769937          89.669255
# min       1.300000     2.300000   947.400000           0.855200
# 25%       5.197000   153.640827   980.500000          48.605000
# 50%       7.009000   211.135417   985.400000         110.500000
# 75%       9.409000   234.539583   989.800000         198.000000
# max      24.440000   359.700000  1011.300000         422.900000
#
#        UVA-Str. (W/m²)  ...   NO (µg/m³)  NO2 (µg/m³)  O3 (µg/m³)  \
# count      7254.000000  ...  6710.000000  6697.000000  6960.00000
# mean          6.877872  ...    20.574591    33.648300    23.00428
# std           4.079769  ...    27.214104    16.616004    14.36668
# min           0.620000  ...    -5.069000    -8.038000     0.00000
# 25%           3.500250  ...     5.059250    21.830000    11.60000
# 50%           5.857500  ...    10.995000    31.250000    21.24000
# 75%           9.485000  ...    24.927500    42.950000    31.20000
# max          26.500000  ...   345.900000   138.800000    99.93000
#
#        SO2 (µg/m³)   CO (mg/m³)  Niederschlag (l/m²)  Str.-Bilanz (W/m²)  \
# count  3136.000000  1277.000000          6969.000000         6727.000000
# mean      6.653081     0.390354             1.430604           35.176040
# std       6.241966     0.386438             3.433907           64.052121
# min      -3.913000     0.023830             0.000000         -501.000000
# 25%       1.823750     0.106500             0.000000           -6.274000
# 50%       5.150000     0.212500             0.040000           23.090000
# 75%      10.320000     0.599100             1.160000           73.195000
# max      44.690000     2.984000            51.100000         1079.000000
#
#        PM10 (µg/m³)  PM2.5 (µg/m³)       KFZ_ges
# count   5843.000000    1451.000000   5845.000000
# mean      20.300021      12.529251  73857.716339
# std       11.865320       8.875281  15191.233885
# min      -64.060000       0.000000  26533.000000
# 25%       12.570000       7.100000  61707.000000
# 50%       18.110000      10.900000  79446.000000
# 75%       25.365000      15.650000  85504.000000
# max      211.700000     185.199375  99162.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# A copy of the original df_total is created for later use, especially for the comparisons when dataframe is further processed (e.g handling of missing values). In particular we want to show that character of the dataset keeps unchanged.

# %%
df_total_original=df_total

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### EDA Preparation

# %% [markdown]
# In order to do a quick exploratory data analysis we use the open source Python module Pandas profiling.
# With this module we are able to create interactive statistical reports and visualizations in a web format.

# %%
eda=pandas_profiling.ProfileReport(df_total)
#eda
eda.to_file(output_file="AirQualityStuttgartEDA.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='variables', max=22.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='correlations', max=6.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='interactions [continuous]', max=441.0, style=ProgressStyl…
# HBox(children=(FloatProgress(value=0.0, description='table', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='missing', max=4.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='warnings', max=3.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='package', max=1.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='build report structure', max=1.0, style=ProgressStyle(des…

# %% [markdown]
# The results of the EDA can be found [here](AirQualityStuttgartEDA.html).

# %% [markdown]
# ### Result Summary

# %% [markdown]
# #### Weather

# %% [markdown]
# ##### Temperature

# %% [markdown]
# All three temperature variables are highly correlated because they represent the `mean`, `max` and `min` values per day.
# For our use case the `mean` values are appropriate and therefore in the following we will drop the `min` and `max` variables.
#
# The `missing values` of 127 will be completed in the chapter [Detection of Missing Values](#Detection-of-Missing-Values).

# %% [markdown]
# ##### Radiation

# %% [markdown]
# The four radiation parameters `Str.-Bilanz (W/m²)`, `Globalstr. (W/m²)`, `UVA-Str. (W/m²)`, and `UVB-Str. (W/m²)` are highly correlated because `UVA` and `UVB` are components of `Global Radiation` (Globalstrahlung), and all three are components of `Radiation Balance`.
#
# The *missing values* of 175 will be completed in the chapter [Detection of Missing Values](#Detection-of-Missing-Values).
#
# *Outliers* will be handled in the following chapter [Outlier Detection and Handling](#Outlier-Detection-and-Handling).
#
# As the four paramaters are intercorrelated we will chose one paramter during the [Features Selection](#Features-Selection).

# %% [markdown]
# ##### Others

# %% [markdown]
# - *Wind*
#
# There are three wind specific variables. The two variables for `Wind speed` are representing mean and max values and are therefore highly correlated.
# For our use case the mean values are appropriate and therefore in the following we will drop the max variables.
# The third one is representing the `Wind Direction`. This variable might have an hugh impact due to the special topography of the city Stuttgart.
#
# The *missing values* will be completed in the chapter [Detection of Missing Values](#Detection-of-Missing-Values).
#
# *Outliers* will be handled in the chapter [Outlier Detection and Handling](#Outlier-Detection-and-Handling).
#
# As two paramaters are interconnected and there is an additial parameter for the wind direction we will select the relevant paramters during the [Features Selection](#Features-Selection).
#
# - *Humidity, Rainfall, Pressure*
#
# The `Rainfall` parameter is special in that way that there are many days without rain and these days are represented by zero values.
#
# The *missing values* will be completed in the chapter [Detection of Missing Values](#Detection-of-Missing-Values).
#
# *Outliers* will be handled in the chapter [Outlier Detection and Handling](#Outlier-Detection-and-Handling).
#
# The relevance of these two parameters will be analyzed in the chapter [Features Selection](#Features-Selection).

# %% [markdown]
# #### Emmissions

# %% [markdown]
# - *NO / NO2 / O3 / SO2 / CO*
#
# Some parameters show some values with a negative sign.  This seems to be unplausible because these variables have units which comprise mass and volume and therefore cannot be negative.
# We assume that these negative values are false values which arose during the recordings and should be corrected. In our case we change the negative sign to positive. This is done in the chapter [Outlier Detection and Handling](#Outlier-Detection-and-Handling).
#
# - *PM10 & PM2.5*
#
# Here again we have negative values which we will handle in the same way as described above.
# Particularly the PM2.5 parameter consists of few observations and therefore a completion for missing values makes no sense.
#
# For both areas we will do following tasks:
# The *missing values* will be completed in the chapter [Detection of Missing Values](#Detection-of-Missing-Values).
# The relevance will be analyzed in the chapter [Features Selection](#Features-Selection).

# %% [markdown]
# #### Traffic

# %% [markdown]
# There are missing values (1,613) due to missing data for the periods 2018-2020 & 2000-2002.
#
# The *missing values* will be completed in the chapter [Detection of Missing Values](#Detection-of-Missing-Values).
#
# *Outliers* will be handled in the chapter [Outlier Detection and Handling](#Outlier-Detection-and-Handling).
#
# The relevance will be analyzed in the chapter [Features Selection](#Features-Selection).

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Detection of Missing Values

# %% [markdown]
# In the areas of detection and handling of missing values there is a variance of different approaches.
# One of the easiest ways is to delete the rows which contains missing values.
# In our case this approach would lead to the fact that our idea of performing a regression on the time series would not work properly.
# Therefore we chose another approach of handling missing values.
# There a different ways to complete the data set. Popular methods use imputer function to fill mean, median or most_frequent values. In our case we use a imputer functions which is based on the K-nearest neigbor algorithm and considers the context of data more accurately.

# %% [markdown]
# First of all in the dataframe df_total we drop the column "Datum" because the normalization function does not work on datetime data type and store it to a new dataframe df_total_woDate.
# We use the min_max_scaler to normalize the data.
# And finally we convert the normalized data represented by numpy array back to an pandas dataframe df_total_norm.

# %%
df_total_woDate = df_total_original.drop('Datum', axis=1)
x = df_total_woDate.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df_total_norm = pd.DataFrame(x_scaled)

# %% [markdown]
# KNN Imputing is a complex method for imputing missing values using k-Nearest Neighbors, in which the KNN algorithm finds other data points similar to one with a missing value within multidimensional space. Further information can be found [here](https://scikit-learn.org/stable/modules/impute.html#knnimpute).

# %%
imputer = KNNImputer()
numData = imputer.fit_transform(df_total_norm)

# %% [markdown]
# Create a list of columns names to recover the pandas dataframe from the above created numpy array.

# %%
listColumns = list(df_total_woDate.columns)

# %% [markdown]
# Create the pandas dataframe with normalized values.

# %%
df_total_norm_KNN = pd.DataFrame(data=numData, columns=listColumns)

# %%
df_total_norm_KNN.head()
# Out:
#    Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)  WG (m/s)  WG (m/s).1  \
# 0    0.353183      0.284143      0.426663     0.913664  0.207442    0.265774
# 1    0.356214      0.305424      0.404860     0.954305  0.239936    0.284831
# 2    0.300606      0.220807      0.381726     0.931037  0.258592    0.204408
# 3    0.381534      0.327445      0.394044     0.814062  0.453811    0.363137
# 4    0.427769      0.376587      0.423960     0.878814  0.249744    0.337727
#
#    WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  UVA-Str. (W/m²)  ...  \
# 0   0.650876     0.694836           0.046035         0.077512  ...
# 1   0.616148     0.774648           0.063872         0.133269  ...
# 2   0.609629     0.763693           0.058996         0.068624  ...
# 3   0.611599     0.665102           0.067925         0.093393  ...
# 4   0.610672     0.661972           0.075450         0.090572  ...
#
#    NO (µg/m³)  NO2 (µg/m³)  O3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  \
# 0    0.064666     0.219793    0.136095     0.294076    0.299669
# 1    0.055155     0.250180    0.169218     0.301483    0.291595
# 2    0.068760     0.295387    0.154108     0.292225    0.275515
# 3    0.037995     0.219616    0.224457     0.356624    0.256191
# 4    0.046781     0.233223    0.160412     0.374113    0.393616
#
#    Niederschlag (l/m²)  Str.-Bilanz (W/m²)  PM10 (µg/m³)  PM2.5 (µg/m³)  \
# 0             0.070239            0.262878      0.273561       0.050621
# 1             0.068908            0.238530      0.277260       0.040728
# 2             0.016434            0.310873      0.304642       0.060373
# 3             0.029147            0.320451      0.273927       0.041480
# 4             0.084540            0.303405      0.279178       0.036069
#
#     KFZ_ges
# 0  0.624580
# 1  0.566377
# 2  0.528893
# 3  0.794192
# 4  0.671693
#
# [5 rows x 21 columns]

# %% [markdown]
# In the next step we denormalize the values:

# %%
numDenorm = min_max_scaler.inverse_transform(df_total_norm_KNN)
df_total_denorm_KNN  = pd.DataFrame(numDenorm, columns=listColumns)

# %% [markdown]
# We generate a dataframe with one column date to concat with our newly created dataframe of denormalized values.

# %%
df_total_Date = df_total[['Datum']]

# %%
df_total = pd.concat([df_total_Date, df_total_denorm_KNN], axis=1, sort=False)

# %%
df_total.head()
# Out:
#        Datum  Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)  WG (m/s)  \
# 0 2000-01-01       3.718         5.700        2.1380        86.83  1.959896
# 1 2000-01-02       3.848         6.706        1.2990        90.69  2.172913
# 2 2000-01-03       1.463         2.706        0.4088        88.48  2.295208
# 3 2000-01-04       4.934         7.747        0.8828        77.37  3.574979
# 4 2000-01-05       6.917        10.070        2.0340        83.52  2.237208
#
#    WG (m/s).1   WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  ...  NO (µg/m³)  \
# 0       7.450  234.922917        991.8            20.2840  ...     17.6266
# 1       7.891  222.511250        996.9            27.8120  ...     14.2886
# 2       6.030  220.181250        996.2            25.7540  ...     19.0638
# 3       9.703  220.885417        989.9            29.5224  ...      8.2660
# 4       9.115  220.554167        989.7            32.6984  ...     11.3496
#
#    NO2 (µg/m³)  O3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  Niederschlag (l/m²)  \
# 0       24.236       13.60        10.38      0.9109               3.5892
# 1       28.698       16.91        10.74      0.8870               3.5212
# 2       35.336       15.40        10.29      0.8394               0.8398
# 3       24.210       22.43        13.42      0.7822               1.4894
# 4       26.208       16.03        14.27      1.1890               4.3200
#
#    Str.-Bilanz (W/m²)  PM10 (µg/m³)  PM2.5 (µg/m³)  KFZ_ges
# 0            -85.6520       11.3772         9.3750  71895.6
# 1           -124.1220       12.3972         7.5428  67668.4
# 2             -9.8208       19.9480        11.1810  64946.0
# 3              5.3120       11.4780         7.6820  84214.4
# 4            -21.6198       12.9260         6.6800  75317.4
#
# [5 rows x 22 columns]

# %%
df_total.describe()
# Out:
#         Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)     WG (m/s)  \
# count  7458.000000   7458.000000   7458.000000  7458.000000  7458.000000
# mean     12.037186     16.741162      7.921511    66.493022     1.981211
# std       7.414490      8.784031      6.567150    11.891172     0.727090
# min     -11.430000     -7.732000    -14.280000     0.051950     0.600000
# 25%       6.259250      9.750500      2.931250    57.700000     1.500000
# 50%      12.205000     16.930000      8.002000    67.390000     1.800000
# 75%      17.730000     23.500000     13.170000    75.560000     2.300000
# max      31.460000     39.540000     24.200000    95.030000     7.155542
#
#         WG (m/s).1    WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  \
# count  7458.000000  7458.000000  7458.000000        7458.000000
# mean      7.645979   194.085750   984.837622         127.081256
# std       3.329761    61.500193     7.725808          89.175475
# min       1.300000     2.300000   947.400000           0.855200
# 25%       5.197000   153.713579   980.585000          48.562500
# 50%       7.009000   211.071147   985.400000         109.900000
# 75%       9.458000   234.489428   989.800000         196.800000
# max      24.440000   359.700000  1011.300000         422.900000
#
#        UVA-Str. (W/m²)  ...   NO (µg/m³)  NO2 (µg/m³)   O3 (µg/m³)  \
# count      7458.000000  ...  7458.000000  7458.000000  7458.000000
# mean          6.886143  ...    20.622069    33.543177    22.987206
# std           4.045396  ...    26.771205    16.139952    14.077765
# min           0.620000  ...    -5.069000    -8.038000     0.000000
# 25%           3.536250  ...     5.287000    22.260000    11.840000
# 50%           5.909400  ...    11.165000    31.175000    21.465000
# 75%           9.458750  ...    24.995000    42.510000    30.887500
# max          26.500000  ...   345.900000   138.800000    99.930000
#
#        SO2 (µg/m³)   CO (mg/m³)  Niederschlag (l/m²)  Str.-Bilanz (W/m²)  \
# count  7458.000000  7458.000000          7458.000000         7458.000000
# mean      6.555690     0.455946             1.429776           35.744829
# std       4.880320     0.296478             3.356878           63.374152
# min      -3.913000     0.023830             0.000000         -501.000000
# 25%       3.107445     0.226937             0.000000           -6.246750
# 50%       5.959850     0.393567             0.060000           23.830000
# 75%       9.152800     0.625345             1.270000           74.417500
# max      44.690000     2.984000            51.100000         1079.000000
#
#        PM10 (µg/m³)  PM2.5 (µg/m³)       KFZ_ges
# count   7458.000000    7458.000000   7458.000000
# mean      19.559665      12.575459  73491.406081
# std       11.047138       6.227805  13980.740621
# min      -64.060000       0.000000  26533.000000
# 25%       12.480000       8.411100  63845.250000
# 50%       17.305000      11.460000  77316.500000
# 75%       24.117500      15.500000  84217.500000
# max      211.700000     185.199375  99162.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ## Adjustment of negative values

# %% [markdown]
# Before we deal with the actual outliers, we first solve the problem with errors that most likely occurred during the collection of data.<br>
# The following variables contain negative values which we assume are documentation errors, as already described above.
# - SO2 (µg/m³),
# - NO2 (µg/m³),
# - NO (µg/m³),
# - PM10 (µg/m³)
#
# Therefore, we will simply change the signs for the negative values.

# %%
#df_total[df_total['SO2 (µg/m³)']<0]
#df_total[df_total['NO2 (µg/m³)']<0]
#df_total[df_total['NO (µg/m³)']<0]
df_total[df_total['PM10 (µg/m³)']<0]
# Out:
#           Datum  Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)  \
# 1325 2003-08-18      23.660         29.74        19.260        56.77
# 1559 2004-04-08       6.756         11.14         3.945        64.81
# 1698 2004-08-25      18.190         21.92         0.000        58.35
# 2471 2006-10-07      14.240         17.48        10.100        70.50
#
#       WG (m/s)  WG (m/s).1   WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  ...  \
# 1325  3.270265       14.55  241.737500        986.8              225.2  ...
# 1559  2.536850       10.39  265.321277        980.7              158.7  ...
# 1698  3.624903       14.11  236.451613        981.5              247.2  ...
# 2471  2.999313       13.96  244.147917        983.5              111.7  ...
#
#       NO (µg/m³)  NO2 (µg/m³)  O3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  \
# 1325    -0.08451       24.800       64.98     0.916894    0.065700
# 1559     8.01700       38.880       29.51     8.323000    0.076090
# 1698     8.65160       24.527       37.83     9.098020    0.041590
# 2471     9.33720       20.064       35.26     3.551000    0.092166
#
#       Niederschlag (l/m²)  Str.-Bilanz (W/m²)  PM10 (µg/m³)  PM2.5 (µg/m³)  \
# 1325               5.0580            -30.1200        -4.315         6.1520
# 1559               0.1600             59.5400       -64.060         9.7238
# 1698               0.6935             41.0800       -25.190        10.2800
# 2471               1.7200              0.1469        -1.308         7.3716
#
#       KFZ_ges
# 1325  67244.0
# 1559  83633.0
# 1698  70514.0
# 2471  64404.0
#
# [4 rows x 22 columns]

# %%
def elNeSign (list_row_name):
    for i in list_row_name:
        df_total[i]=df_total[i].astype('str')
        df_total[i]=df_total[i].str.replace('-','')
        df_total[i]=df_total[i].astype('float')

list_row_name =['SO2 (µg/m³)', 'NO2 (µg/m³)', 'NO (µg/m³)', 'PM10 (µg/m³)']
elNeSign(list_row_name)

# %%
#df_total[df_total['SO2 (µg/m³)']<0]
#df_total[df_total['NO2 (µg/m³)']<0]
#df_total[df_total['NO (µg/m³)']<0]
df_total[df_total['PM10 (µg/m³)']<0]
# Out:
# Empty DataFrame
# Columns: [Datum, Temp. (°C), Temp. (°C).1, Temp. (°C).2, Feuchte (%), WG (m/s), WG (m/s).1, WR (Grad), Druck (hPa), Globalstr. (W/m²), UVA-Str. (W/m²), UVB-Str. (W/m²), NO (µg/m³), NO2 (µg/m³), O3 (µg/m³), SO2 (µg/m³), CO (mg/m³), Niederschlag (l/m²), Str.-Bilanz (W/m²), PM10 (µg/m³), PM2.5 (µg/m³), KFZ_ges]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_total.describe()
# Out:
#         Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)     WG (m/s)  \
# count  7458.000000   7458.000000   7458.000000  7458.000000  7458.000000
# mean     12.037186     16.741162      7.921511    66.493022     1.981211
# std       7.414490      8.784031      6.567150    11.891172     0.727090
# min     -11.430000     -7.732000    -14.280000     0.051950     0.600000
# 25%       6.259250      9.750500      2.931250    57.700000     1.500000
# 50%      12.205000     16.930000      8.002000    67.390000     1.800000
# 75%      17.730000     23.500000     13.170000    75.560000     2.300000
# max      31.460000     39.540000     24.200000    95.030000     7.155542
#
#         WG (m/s).1    WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  \
# count  7458.000000  7458.000000  7458.000000        7458.000000
# mean      7.645979   194.085750   984.837622         127.081256
# std       3.329761    61.500193     7.725808          89.175475
# min       1.300000     2.300000   947.400000           0.855200
# 25%       5.197000   153.713579   980.585000          48.562500
# 50%       7.009000   211.071147   985.400000         109.900000
# 75%       9.458000   234.489428   989.800000         196.800000
# max      24.440000   359.700000  1011.300000         422.900000
#
#        UVA-Str. (W/m²)  ...   NO (µg/m³)  NO2 (µg/m³)   O3 (µg/m³)  \
# count      7458.000000  ...  7458.000000  7458.000000  7458.000000
# mean          6.886143  ...    20.628170    33.558937    22.987206
# std           4.045396  ...    26.766503    16.107154    14.077765
# min           0.620000  ...     0.047220     0.000000     0.000000
# 25%           3.536250  ...     5.287000    22.260000    11.840000
# 50%           5.909400  ...    11.165000    31.175000    21.465000
# 75%           9.458750  ...    24.995000    42.510000    30.887500
# max          26.500000  ...   345.900000   138.800000    99.930000
#
#        SO2 (µg/m³)   CO (mg/m³)  Niederschlag (l/m²)  Str.-Bilanz (W/m²)  \
# count  7458.000000  7458.000000          7458.000000         7458.000000
# mean      6.631525     0.455946             1.429776           35.744829
# std       4.776749     0.296478             3.356878           63.374152
# min       0.000000     0.023830             0.000000         -501.000000
# 25%       3.138250     0.226937             0.000000           -6.246750
# 50%       5.959850     0.393567             0.060000           23.830000
# 75%       9.152800     0.625345             1.270000           74.417500
# max      44.690000     2.984000            51.100000         1079.000000
#
#        PM10 (µg/m³)  PM2.5 (µg/m³)       KFZ_ges
# count   7458.000000    7458.000000   7458.000000
# mean      19.585107      12.575459  73491.406081
# std       11.001963       6.227805  13980.740621
# min        0.000000       0.000000  26533.000000
# 25%       12.481200       8.411100  63845.250000
# 50%       17.310000      11.460000  77316.500000
# 75%       24.133000      15.500000  84217.500000
# max      211.700000     185.199375  99162.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ## Outlier Detection and Handling

# %% [markdown]
# ### Outlier Detection using Boxplots

# %%
plt.figure(figsize=(14, 7))
sns.set_style("darkgrid")
sns.boxplot(data=df_total.drop(columns=[
    'Datum',
    'Temp. (°C)',
    'Temp. (°C).1',
    'Temp. (°C).2',
    'Feuchte (%)',
    'WG (m/s)',
    'WG (m/s).1',
    'WR (Grad)',
    'Druck (hPa)',
    'Globalstr. (W/m²)',
    'UVA-Str. (W/m²)',
    'UVB-Str. (W/m²)',
    'NO (µg/m³)',
    'NO2 (µg/m³)',
    'O3 (µg/m³)',
    'SO2 (µg/m³)',
    'CO (mg/m³)',
    'Niederschlag (l/m²)',
    'Str.-Bilanz (W/m²)',
    'PM10 (µg/m³)',
    'PM2.5 (µg/m³)',
    'KFZ_ges'
]))
plt.ylabel("Original values")
plt.show()

# %% [markdown]
# The outlier detection must be viewed and edited column by column! We pass here the column that is processed to the variable `data` as a numpy Arrey.

# %%
data = df_total['WG (m/s)'].values
#'Datum','Temp. (°C)','Temp. (°C).1','Temp. (°C).2','Feuchte (%)','WG (m/s)','WG (m/s).1','WR (Grad)','Druck (hPa)',
#'Globalstr. (W/m²)','UVA-Str. (W/m²)','UVB-Str. (W/m²)','NO (µg/m³)','NO2 (µg/m³)','O3 (µg/m³)','SO2 (µg/m³)','CO (mg/m³)',
#'Niederschlag (l/m²)','Str.-Bilanz (W/m²)','PM10 (µg/m³)','PM2.5 (µg/m³)','KFZ_ges'

# %% [markdown]
# ### Outlierhandling using Z score

# %% [markdown]
# Formula for Z score = (Observation — Mean)/Standard Deviation
#
# z = (X — μ) / σ
#
# We find the z score for each of the data point in the dataset and if the z score is greater than 3 than we can classify that point as an outlier. Any point outside of 3 standard deviations would be an outlier.

# %%
outliers=[]
def detect_outlier(data_1):
    threshold=3
    mean_1 = np.mean(data_1)
    std_1 =np.std(data_1)
    
    for y in data_1:
        z_score= (y - mean_1)/std_1 
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

# %%
outlier_datapoint = detect_outlier(data)
outliers=[] # ththe list must be emptied, otherwise double entry of the values
min_val = min(outlier_datapoint)
max_val = max(outlier_datapoint)

print('Min value: ', min_val)
print('Max value: ', max_val)
print('Whole outliers: ', outlier_datapoint)
# Out:
# Min value:  4.166604166666667
# Max value:  7.155541666666665
# Whole outliers:  [5.954020833333332, 4.6130416666666685, 4.8475416666666655, 4.374937500000001, 4.5473541666666675, 4.197979166666667, 6.354854166666666, 4.5307916666666666, 4.2399375, 4.497625, 4.315312500000001, 4.623124999999999, 4.845333333333333, 4.845333333333333, 4.521541666666666, 4.166604166666667, 4.3536875, 6.020583333333332, 4.445708333333332, 4.884249999999999, 6.542354166666665, 5.094375, 4.506749999999999, 6.643437499999998, 4.672166666666667, 4.348708333333334, 4.8335625, 5.243895833333336, 4.745520833333333, 5.192395833333334, 4.300875, 4.879458333333333, 4.451020833333334, 4.337020833333333, 4.753458333333334, 5.292666666666668, 4.478895833333332, 4.403291666666666, 4.818416666666667, 5.456854166666666, 4.627604166666667, 4.3709791666666655, 4.496708333333333, 5.053645833333334, 4.944583333333333, 4.590708333333335, 5.066416666666666, 4.2456249999999995, 4.491833333333334, 4.521, 4.308895833333334, 4.257049999999999, 4.4578125, 7.155541666666665, 5.296937500000001, 4.8145, 4.452354166666666, 4.173958333333332, 4.680208333333333, 4.609083333333334, 4.7230625, 4.4219791666666675, 4.983768749999999, 4.334729166666667, 4.895083333333332, 4.340479166666666, 5.216583333333335, 5.564958333333333, 4.930645833333334, 5.2733333333333325, 5.139104166666669, 4.789791666666666, 4.30009375, 5.148750000000001, 4.183270833333333, 4.541645833333334, 4.359562500000001, 4.319083333333333, 4.3220625, 4.201666666666666, 6.062125000000001, 4.371312500000001, 5.751062499999999, 4.597479166666667, 4.3765625, 5.054583333333334, 5.0140625000000005, 4.795875, 4.425787234042551, 5.75383333333333, 5.0142083333333325, 4.184041666666666, 5.1, 4.7, 4.9, 4.3, 4.4, 4.2, 4.9, 4.7, 6.6, 5.0, 4.6]

# %% [markdown]
# ***Replacing all the values higher then `min_val` with the value of `min_val`***

# %%
df_total.loc[df_total["WG (m/s)"] > min_val,"WG (m/s)"] = min_val

# %% [markdown]
# ***Testing if in the row belowe are values higher then `min_val`***

# %%
df_total[df_total['WG (m/s)'] > min_val]
# Out:
# Empty DataFrame
# Columns: [Datum, Temp. (°C), Temp. (°C).1, Temp. (°C).2, Feuchte (%), WG (m/s), WG (m/s).1, WR (Grad), Druck (hPa), Globalstr. (W/m²), UVA-Str. (W/m²), UVB-Str. (W/m²), NO (µg/m³), NO2 (µg/m³), O3 (µg/m³), SO2 (µg/m³), CO (mg/m³), Niederschlag (l/m²), Str.-Bilanz (W/m²), PM10 (µg/m³), PM2.5 (µg/m³), KFZ_ges]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ***Testing if the highest value in the row belowe is not higher then `min_val`***

# %%
max(df_total['WG (m/s)'])
# Out:
# 4.166604166666667

# %%
plt.figure(figsize=(14, 7))
sns.set_style("darkgrid")
sns.boxplot(data=df_total.drop(columns=[
    'Datum',
    'Temp. (°C)',
    'Temp. (°C).1',
    'Temp. (°C).2',
    'Feuchte (%)',
    #'WG (m/s)',
    'WG (m/s).1',
    'WR (Grad)',
    'Druck (hPa)',
    'Globalstr. (W/m²)',
    'UVA-Str. (W/m²)',
    'UVB-Str. (W/m²)',
    'NO (µg/m³)',
    'NO2 (µg/m³)',
    'O3 (µg/m³)',
    'SO2 (µg/m³)',
    'CO (mg/m³)',
    'Niederschlag (l/m²)',
    'Str.-Bilanz (W/m²)',
    'PM10 (µg/m³)',
    'PM2.5 (µg/m³)',
    'KFZ_ges'
]))
plt.ylabel("Original values")
plt.show()

# %% [markdown]
# ### Outlierhandling using IQR

# %%
data_IQR = df_total['NO2 (µg/m³)'].values
#'Datum','Temp. (°C)','Temp. (°C).1','Temp. (°C).2','Feuchte (%)','WG (m/s)','WG (m/s).1','WR (Grad)','Druck (hPa)',
#'Globalstr. (W/m²)','UVA-Str. (W/m²)','UVB-Str. (W/m²)','NO (µg/m³)','NO2 (µg/m³)','O3 (µg/m³)','SO2 (µg/m³)','CO (mg/m³)',
#'Niederschlag (l/m²)','Str.-Bilanz (W/m²)','PM10 (µg/m³)','PM2.5 (µg/m³)','KFZ_ges'

# %%
plt.figure(figsize=(14, 7))
sns.set_style("darkgrid")
sns.boxplot(data=df_total.drop(columns=[
    'Datum',
    'Temp. (°C)',
    'Temp. (°C).1',
    'Temp. (°C).2',
    'Feuchte (%)',
    'WG (m/s)',
    'WG (m/s).1',
    'WR (Grad)',
    'Druck (hPa)',
    'Globalstr. (W/m²)',
    'UVA-Str. (W/m²)',
    'UVB-Str. (W/m²)',
    'NO (µg/m³)',
    #'NO2 (µg/m³)',
    'O3 (µg/m³)',
    'SO2 (µg/m³)',
    'CO (mg/m³)',
    'Niederschlag (l/m²)',
    'Str.-Bilanz (W/m²)',
    'PM10 (µg/m³)',
    'PM2.5 (µg/m³)',
    'KFZ_ges'
]))
plt.ylabel("Original values")
plt.show()

# %% [markdown]
# IQR tells how spread the middle values are. It can be used to tell when a value is too far from the middle.
# An outlier is a point which falls more than 1.5 times the interquartile range above the third quartile or below the first quartile.

# %%
sorted(data_IQR) #sorting the dataset

q1, q3= np.percentile(data_IQR,[25,75]) #finding first quartile and third quartile

iqr = q3 - q1 #find the IQR which is the difference between third and first quartile

lower_bound = q1 -(1.5 * iqr) #find lower bound
upper_bound = q3 +(1.5 * iqr) #find upper bound
print('Lower bound: ', lower_bound)
print('Upper bound: ', upper_bound)
# Out:
# Lower bound:  -8.115000000000002
# Upper bound:  72.88499999999999

# %% [markdown]
# Anything outside of `lower_bound` and `upper_bound` is an outlier.

# %%
#df_total[(df_total['NO2 (µg/m³)'] < lower_bound) | (df_total['NO2 (µg/m³)'] > upper_bound)]

# %%
df_total[df_total['NO2 (µg/m³)'] < lower_bound]
# Out:
# Empty DataFrame
# Columns: [Datum, Temp. (°C), Temp. (°C).1, Temp. (°C).2, Feuchte (%), WG (m/s), WG (m/s).1, WR (Grad), Druck (hPa), Globalstr. (W/m²), UVA-Str. (W/m²), UVB-Str. (W/m²), NO (µg/m³), NO2 (µg/m³), O3 (µg/m³), SO2 (µg/m³), CO (mg/m³), Niederschlag (l/m²), Str.-Bilanz (W/m²), PM10 (µg/m³), PM2.5 (µg/m³), KFZ_ges]
# Index: []
#
# [0 rows x 22 columns]

# %%
df_total[df_total['NO2 (µg/m³)'] > upper_bound]
# Out:
#           Datum  Temp. (°C)  Temp. (°C).1  Temp. (°C).2  Feuchte (%)  \
# 13   2000-01-14      1.1770         5.805       -1.6070        78.77
# 545  2001-06-29     21.1700        27.910       14.3600        51.31
# 706  2001-12-07      3.3630         6.081        2.2530        77.94
# 707  2001-12-08      1.9800         4.852       -0.1797        74.84
# 708  2001-12-09      0.4991         4.252       -2.0390        63.14
# ...         ...         ...           ...           ...          ...
# 5185 2014-03-13     10.8700        19.730        3.9970        48.43
# 5186 2014-03-14     11.2300        20.170        4.1430        50.11
# 5203 2014-03-31     13.7700        21.600        7.4350        50.74
# 5204 2014-04-01     14.8100        22.370        8.2780        49.29
# 6232 2017-01-23     -5.5000         0.000       -9.2000        76.40
#
#       WG (m/s)  WG (m/s).1   WR (Grad)  Druck (hPa)  Globalstr. (W/m²)  ...  \
# 13    1.243110       3.189  171.646667       988.50              37.50  ...
# 545   2.068632       6.324  136.545851       991.20             306.80  ...
# 706   1.679437       5.442  123.062766      1001.00              14.73  ...
# 707   1.908590       6.862   58.942500      1004.00              51.40  ...
# 708   1.566560       5.981   52.701875      1004.00              60.23  ...
# ...        ...         ...         ...          ...                ...  ...
# 5185  1.671567       5.197  134.966319       996.90             164.40  ...
# 5186  1.867690       6.765  183.089125       994.70             164.90  ...
# 5203  1.687074       4.610  138.791064       984.30             169.70  ...
# 5204  1.586500       6.079  149.334565       982.30             184.60  ...
# 6232  1.400000       3.900   39.400000       987.59              68.30  ...
#
#       NO (µg/m³)  NO2 (µg/m³)  O3 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  \
# 13       178.500       87.794       9.334      19.6200     1.30600
# 545       15.250       73.690      45.460       0.1563     0.33390
# 706       53.530       80.310       6.416       3.2480     0.73958
# 707       72.140       81.510       9.093       7.6060     0.52580
# 708       40.430       87.390      13.890       6.5360     0.48090
# ...          ...          ...         ...          ...         ...
# 5185      47.160       79.950       7.126      13.5100     0.36794
# 5186      51.760       79.910       8.895      10.5382     0.36664
# 5203      45.940       76.480      24.280      12.7976     0.40470
# 5204      46.420       74.040       7.875      12.3196     0.37518
# 6232     195.028       73.026       2.700      25.5040     1.33156
#
#       Niederschlag (l/m²)  Str.-Bilanz (W/m²)  PM10 (µg/m³)  PM2.5 (µg/m³)  \
# 13                  0.023           -14.04000        22.180      25.280000
# 545                 0.000           135.34000        28.082      15.224000
# 706                 0.010           -11.76460        23.070      18.742000
# 707                 0.030           -13.75122        23.310      17.720000
# 708                 0.030            -5.66340        23.600      22.170000
# ...                   ...                 ...           ...            ...
# 5185                0.000            29.07000        39.484      27.860000
# 5186                0.000            28.78000        34.432      27.860000
# 5203                0.000            47.22000        37.090      25.590000
# 5204                0.000            64.50000        41.240      25.890000
# 6232                0.000           -31.20000        83.300      28.154286
#
#       KFZ_ges
# 13    76730.2
# 545   80264.8
# 706   67961.0
# 707   61173.8
# 708   54129.6
# ...       ...
# 5185  88587.0
# 5186  91467.0
# 5203  87694.0
# 5204  90095.0
# 6232  85395.0
#
# [156 rows x 22 columns]

# %% [markdown]
# ***Replacing all the values higher then `upper_bound` with the value of `upper_bound`***

# %%
df_total.loc[df_total["NO2 (µg/m³)"] > upper_bound,"NO2 (µg/m³)"] = upper_bound

# %% [markdown]
# ***Testing if in the row belowe are values higher then `upper_bound`***

# %%
df_total[df_total['NO2 (µg/m³)'] > upper_bound]
# Out:
# Empty DataFrame
# Columns: [Datum, Temp. (°C), Temp. (°C).1, Temp. (°C).2, Feuchte (%), WG (m/s), WG (m/s).1, WR (Grad), Druck (hPa), Globalstr. (W/m²), UVA-Str. (W/m²), UVB-Str. (W/m²), NO (µg/m³), NO2 (µg/m³), O3 (µg/m³), SO2 (µg/m³), CO (mg/m³), Niederschlag (l/m²), Str.-Bilanz (W/m²), PM10 (µg/m³), PM2.5 (µg/m³), KFZ_ges]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ***Testing if the highest value in the row belowe is not higher then `upper_bound`***

# %%
max(df_total['NO2 (µg/m³)'])
# Out:
# 72.88499999999999

# %%
plt.figure(figsize=(14, 7))
sns.set_style("darkgrid")
sns.boxplot(data=df_total.drop(columns=[
    'Datum',
    'Temp. (°C)',
    'Temp. (°C).1',
    'Temp. (°C).2',
    'Feuchte (%)',
    'WG (m/s)',
    'WG (m/s).1',
    'WR (Grad)',
    'Druck (hPa)',
    'Globalstr. (W/m²)',
    'UVA-Str. (W/m²)',
    'UVB-Str. (W/m²)',
    'NO (µg/m³)',
    #'NO2 (µg/m³)',
    'O3 (µg/m³)',
    'SO2 (µg/m³)',
    'CO (mg/m³)',
    'Niederschlag (l/m²)',
    'Str.-Bilanz (W/m²)',
    'PM10 (µg/m³)',
    'PM2.5 (µg/m³)',
    'KFZ_ges'
]))
plt.ylabel("Original values")
plt.show()

# %% [markdown]
# ### Outlierhandling using Log

# %%
#df_total['WG (m/s)'] = [np.log(x) for x in df_total['WG (m/s)']]
#df_total['NO (µg/m³)'] = [np.log(x) for x in df_total['NO (µg/m³)']]
#df_total['NO2 (µg/m³)'] = [np.log(x) for x in df_total['NO2 (µg/m³)']]
#df_total['SO2 (µg/m³)'] = [np.log(x) for x in df_total['SO2 (µg/m³)']]
#df_total['Niederschlag (l/m²)'] = [np.log(x) for x in df_total['Niederschlag (l/m²)']]
#df_total['PM10 (µg/m³)'] = [np.log(x) for x in df_total['PM10 (µg/m³)']]

# %% [markdown]
# ## Plots after data preparation

# %% [raw]
# df_total_denorm_KNN.describe()
# df_total_denorm_KNN.info()

# %%
plt.figure(figsize=(14, 7))
sns.set_style("darkgrid")
sns.boxplot(data=df_total.drop(columns=[
    'Datum',
    #'Temp. (°C)',
    'Temp. (°C).1',
    'Temp. (°C).2',
    'Feuchte (%)',
    #'WG (m/s)',
    'WG (m/s).1',
    #'WR (Grad)',
    'Druck (hPa)',
    #'Globalstr. (W/m²)',
    'UVA-Str. (W/m²)',
    'UVB-Str. (W/m²)',
    #'NO (µg/m³)',
    #'NO2 (µg/m³)',
    'O3 (µg/m³)',
    #'SO2 (µg/m³)',
    #'CO (mg/m³)',
    #'Niederschlag (l/m²)',
    'Str.-Bilanz (W/m²)',
    #'PM10 (µg/m³)',
    'PM2.5 (µg/m³)',
    'KFZ_ges'
]))
#plt.title("Distribution of normalized temperature, humidity and windspeed")
plt.ylabel("Original values")
plt.show()

# %%
corr_total = df_total.corr()
corr_total_original = df_total_original.corr()

fig, ax = plt.subplots(1, 2, figsize=(17, 7))
colormap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr_total, cmap=colormap, annot=False, fmt=".2f", ax=ax[0]).set_title("Correlations of complete data")
sns.heatmap(corr_total_original, cmap=colormap, annot=False, fmt=".2f", ax=ax[1]).set_title("Correlations of original data")
plt.show()

# %% [markdown]
# We see that the data "characters" and patterns after completing missing data has not changed significantly so that we can continue with the completed data.

# %% [markdown]
# In the following we see that the time gaps for particultes were filled by the imputer function.

# %% [markdown]
# First we show the whole period 2000-2020.

# %%
sns.set(rc={'figure.figsize':(15.7,8.27)})

ax=sns.lineplot(x="Datum", y="PM10 (µg/m³)", data=df_total)
ax=sns.lineplot(x="Datum", y="PM10 (µg/m³)", data=df_total_original)

# %% [markdown]
# We can zoom in for period starting on 01 January 2013.

# %%
sns.set(rc={'figure.figsize':(15.7,8.27)})

ax=sns.lineplot(x="Datum", y="PM10 (µg/m³)", data=df_total[df_total["Datum"] > '2013-01-01 00:00:00'])
ax=sns.lineplot(x="Datum", y="PM10 (µg/m³)", data=df_total_original[df_total_original["Datum"] > '2013-01-01 00:00:00'])

# %% [markdown]
# Further zoom in for period 2018-2019.

# %%
sns.set(rc={'figure.figsize':(15.7,8.27)})

ax=sns.lineplot(x="Datum", y="PM10 (µg/m³)", data=df_total[(df_total["Datum"] > '2018-01-01 00:00:00')&(df_total["Datum"] < '2019-12-31 00:00:00')])
ax=sns.lineplot(x="Datum", y="PM10 (µg/m³)", data=df_total_original[(df_total_original["Datum"] > '2018-01-01 00:00:00')&(df_total_original["Datum"] < '2019-12-31 00:00:00')])

# %% [markdown]
# We also plot and analyze the data for traffic. Here we realized that the imputting method does not work optimally for this attribute. In the period 2000-2002 we see an decreasing trend of the traffic data. We would expect an increase trend in analogy to the real data 2003-2018. The populated period at the end of the time series also seem to to decrease. Here we also would expect an increase behaviour.
# In this case we would chose another imputing method based on a linear regression approach. Due to the restricted time and the higher focus an Machine Learning we will continue with this data though.

# %%
sns.set(rc={'figure.figsize':(15.7,8.27)})

ax=sns.lineplot(x="Datum", y="KFZ_ges", data=df_total)
ax=sns.lineplot(x="Datum", y="KFZ_ges", data=df_total_original)

# %% [markdown]
# ## Features Selection

# %% [markdown]
# The goals of the feature selections are:
# - Eliminate redundancies and correlations of different features, e.g. at the level of temperature and radiation parameters
# - Reduce computational time / cost
# - Improve the prediction accuracy
# - Produce a more interpretable model

# %% [markdown]
# We also realized that for some features a further feature processing would be helpful. For example the feature `Wind Direction` could be transformed in 8 cardinal points like North-East, South, South-West etc. Due to the restricted time and the higher focus an Machine Learning we will continue with this data.

# %% [markdown]
# Basesd on Scikit-Learn the feature importance is calculated with `sklearn.feature_selection.mutual_info_regression` (more information can be found here on [Scikit](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_regression.html?highlight=mutual_info_regression#sklearn.feature_selection.mutual_info_regression)).
# The visualization is generated with the help of [yellowbrick](https://www.scikit-yb.org/en/latest/api/target/feature_correlation.html).

# %%
# !pip install yellowbrick

# %% [markdown]
# **In our use case there are no discrete features. Therefore we set all items in the discrete list to False.**

# %%
X, y = df_total.drop(['Datum','PM10 (µg/m³)','PM2.5 (µg/m³)'], axis=1).to_numpy(), df_total['PM10 (µg/m³)'].to_numpy()

# Create a list of the feature names
features = np.array(list(df_total.drop(['Datum','PM10 (µg/m³)','PM2.5 (µg/m³)'], axis=1)))

# Create a list of the discrete features
discrete = [False for _ in range(len(features))]
#discrete[1] = True #there are no discrete features in our use case, all of them are continous

# Instantiate the visualizer
visualizer = FeatureCorrelation(method='mutual_info-regression', labels=features, size=(1000, 500))

visualizer.fit(X, y, discrete_features=discrete, random_state=0)
visualizer.show()

# %% [markdown]
# In the the next step we have a look on the Pearson's correlations.
# Here, in contrary to the approach above ('mututal information for regresson'), this approach handles continous and dicrete variables equally.
# The Pearson's correlation further helps to understand the direction of dependencies between features and the target variable.

# %%
X, y = df_total.drop(['Datum','PM10 (µg/m³)','PM2.5 (µg/m³)'], axis=1).to_numpy(), df_total['PM10 (µg/m³)'].to_numpy()

# Create a list of the feature names
features = np.array(list(df_total.drop(['Datum','PM10 (µg/m³)','PM2.5 (µg/m³)'], axis=1)))

# Instantiate the visualizer
visualizer = FeatureCorrelation(method='pearson', labels=features, size=(1000, 500))

visualizer.fit(X, y)
visualizer.show()

# %% [markdown]
# The first analysis based on `Mutual Information` shows a higher significance (>0.1) of following parameter:
# - Rainfall
# - NO
# - NO2
# - Wind Direction
# - Wind Speed (mean)
# - Temperature (mean)
# - Temperature (max)
#
# The second analysis based on `Pearson's Correlation` and recommendations of Cohen* we decided to chose the features with correlations higher than 0.2 (absolute values):
# - Wind Direction
# - Wind Speed (mean)
# - Wind Speed (max)
# - CO
# - SO2
# - NO2
# - NO
# - Pressure
#
#
#
# *According to Cohen r = 0.1 indicates a small impact, r = 0.3 a middle impact and r = 0.5 a strong impact.

# %% [markdown]
# In the case of temperature, we only chose one temperature attribute, the `Temperature (mean)`. The other temperature related attributes flow into the calculation of the mean value and therefore can be neglected.
#
# For `Wind Speed` we also take the mean value, which shows a better dependency / correlation to the target value.
#
# The attribute that we expected to have the highest impact, `traffic volume`, shows indeed a very poor impact on the target variable `particulates`. Therefore, this attribute will be dropped.

# %% [markdown]
# **According to the feature selection procedure used above, we decide on the following variables and save them in a new data frame df_for_ML.**

# %%
df_for_ML = df_total[['Datum', 
                      'Temp. (°C)', 
                      #'Temp. (°C).1', 
                      #'Temp. (°C).2',  
                      #'Feuchte (%)',
                      'WG (m/s)', 
                      #'WG (m/s).1', 
                      'WR (Grad)', 
                      'Druck (hPa)',
                      #'Globalstr. (W/m²)', 
                      #'UVA-Str. (W/m²)', 
                      #'UVB-Str. (W/m²)',  
                      'NO (µg/m³)', 
                      'NO2 (µg/m³)', 
                      #'O3 (µg/m³)', 
                      'SO2 (µg/m³)', 
                      'CO (mg/m³)',
                      'Niederschlag (l/m²)', 
                      #'Str.-Bilanz (W/m²)', 
                      'PM10 (µg/m³)',
                      #'PM2.5 (µg/m³)',  
                      #'KFZ_ges'
                     ]]

# %%
df_for_ML.head(5)
# Out:
#        Datum  Temp. (°C)  WG (m/s)   WR (Grad)  Druck (hPa)  NO (µg/m³)  \
# 0 2000-01-01       3.718  1.959896  234.922917        991.8     17.6266
# 1 2000-01-02       3.848  2.172913  222.511250        996.9     14.2886
# 2 2000-01-03       1.463  2.295208  220.181250        996.2     19.0638
# 3 2000-01-04       4.934  3.574979  220.885417        989.9      8.2660
# 4 2000-01-05       6.917  2.237208  220.554167        989.7     11.3496
#
#    NO2 (µg/m³)  SO2 (µg/m³)  CO (mg/m³)  Niederschlag (l/m²)  PM10 (µg/m³)
# 0       24.236        10.38      0.9109               3.5892       11.3772
# 1       28.698        10.74      0.8870               3.5212       12.3972
# 2       35.336        10.29      0.8394               0.8398       19.9480
# 3       24.210        13.42      0.7822               1.4894       11.4780
# 4       26.208        14.27      1.1890               4.3200       12.9260

# %% [markdown]
# Before we export the dataframe to a csv file we cleanse the column names.

# %%
df_for_ML.columns
# Out:
# Index(['Datum', 'Temp. (°C)', 'WG (m/s)', 'WR (Grad)', 'Druck (hPa)',
#        'NO (µg/m³)', 'NO2 (µg/m³)', 'SO2 (µg/m³)', 'CO (mg/m³)',
#        'Niederschlag (l/m²)', 'PM10 (µg/m³)'],
#       dtype='object')

# %%
newColumnNames=['Datum', 'Temp', 'WG', 'WR', 'Druck',
       'NO', 'NO2', 'SO2', 'CO',
       'Niederschlag', 'PM10']

# %%
df_for_ML.columns = newColumnNames

# %%
df_for_ML.columns
# Out:
# Index(['Datum', 'Temp', 'WG', 'WR', 'Druck', 'NO', 'NO2', 'SO2', 'CO',
#        'Niederschlag', 'PM10'],
#       dtype='object')

# %% [markdown]
# Now we export the dataframe to a csv.

# %%
df_for_ML.to_csv('df_for_ML.csv', index=False)
